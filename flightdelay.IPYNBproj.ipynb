# %%
import pandas as pd

# %%
import codecs
import numpy as np
import csv
from StringIO import StringIO

# %%
pwd
# Out:
# u'C:\\Users\\Admin'

# %%
cd C:\E drive\data science\assign2
# Out:
# C:\E drive\data science\assign2

# %%
with codecs.open('D_flight.csv', 'r') as f:
    data = f.read()

# %%
Airport=pd.read_csv("Airport_Lookup.csv",header=0)

# %%
Carrier=pd.read_csv("Carrier_Lookup.csv",header=0)

# %%
d_flights = pd.read_csv(StringIO(data.replace('”', '"')), sep=',', encoding='utf-8', quoting=csv.QUOTE_NONNUMERIC, dtype={'MONTH':'int64', 'DAY_OF_MONTH':'int64', 'DAY_OF_WEEK':'int64', 'UNIQUE_CARRIER':'category', 'ORIGIN_AIRPORT_ID':'int64', 'DEST_AIRPORT_ID':'int64', 'CRS_DEP_TIME':'int64', 'CRS_ARR_TIME':'int64', 'ARR_DELAY':'float64', 'CRS_ELAPSED_TIME':'int64', 'DISTANCE':'int64'})

# %%
d_flights.head()
# Out:
#    MONTH  DAY_OF_MONTH  DAY_OF_WEEK UNIQUE_CARRIER  ORIGIN_AIRPORT_ID  \
# 0      1             1            7             AA              14100
# 1      1             2            1             AA              14100
# 2      1             1            7             AA              14747
# 3      1             2            1             AA              14747
# 4      1             3            2             AA              14747
#
#    DEST_AIRPORT_ID  CRS_DEP_TIME  CRS_ARR_TIME  ARR_DELAY  CRS_ELAPSED_TIME  \
# 0            14747          2050          2355       -9.0               365
# 1            14747          2050          2355       37.0               365
# 2            11057          1117          1920      305.0               303
# 3            11057          1117          1920        0.0               303
# 4            11057          1117          1920      -25.0               303
#
#    DISTANCE
# 0      2378
# 1      2378
# 2      2279
# 3      2279
# 4      2279

# %%
d_flights.dtypes
# Out:
# MONTH                   int64
# DAY_OF_MONTH            int64
# DAY_OF_WEEK             int64
# UNIQUE_CARRIER       category
# ORIGIN_AIRPORT_ID       int64
# DEST_AIRPORT_ID         int64
# CRS_DEP_TIME            int64
# CRS_ARR_TIME            int64
# ARR_DELAY             float64
# CRS_ELAPSED_TIME        int64
# DISTANCE                int64
# dtype: object

# %%
y=d_flights['UNIQUE_CARRIER']
y.value_counts()
# Out:
# AS    117668
# DL     46402
# OO     45627
# WN     31187
# UA     21159
# AA     19345
# VX      4460
# B6      3971
# NK      3588
# F9      1685
# HA      1479
# Name: UNIQUE_CARRIER, dtype: int64

# %%
y=d_flights['MONTH']
y.value_counts()
# Out:
# 8     29324
# 7     28846
# 6     26980
# 9     25961
# 10    25591
# 5     24662
# 12    23856
# 11    23673
# 3     23134
# 4     22788
# 1     21926
# 2     19830
# Name: MONTH, dtype: int64

# %%
y=d_flights['DAY_OF_MONTH']
y.value_counts()
# Out:
# 26    10016
# 27    10007
# 20     9960
# 17     9931
# 13     9896
# 22     9879
# 19     9853
# 12     9830
# 21     9821
# 10     9808
# 15     9783
# 16     9773
# 6      9769
# 18     9721
# 14     9699
# 5      9692
# 28     9691
# 25     9682
# 9      9661
# 24     9649
# 8      9628
# 1      9626
# 23     9623
# 2      9598
# 7      9585
# 11     9578
# 3      9567
# 4      9440
# 30     9081
# 29     9034
# 31     5690
# Name: DAY_OF_MONTH, dtype: int64

# %%
y=d_flights['DAY_OF_WEEK']
y.value_counts()
# Out:
# 5    43805
# 1    43731
# 4    43460
# 3    42926
# 2    42248
# 7    42207
# 6    38194
# Name: DAY_OF_WEEK, dtype: int64

# %%
y=d_flights['ORIGIN_AIRPORT_ID']
y.value_counts()
# Out:
# 14747    137176
# 11884     11678
# 12892     10178
# 14771      9728
# 11292      8766
# 12889      7312
# 10299      6630
# 14869      6363
# 14107      6118
# 13930      5244
# 14057      4569
# 14893      4564
# 13487      4291
# 13796      4174
# 11298      4127
# 14831      3920
# 14679      3834
# 14252      3810
# 10713      3247
# 10397      3128
# 12478      2639
# 12266      2502
# 14908      2480
# 11433      2312
# 10721      2075
# 11618      1919
# 12173      1723
# 11630      1700
# 13830      1438
# 12523      1413
#           ...
# 14492       560
# 15376       493
# 13303       463
# 11697       451
# 14489       377
# 13495       365
# 14683       365
# 15304       365
# 13871       365
# 10140       364
# 14828       299
# 14689       292
# 13851       255
# 10849       236
# 12339       235
# 10994       209
# 11109       165
# 12278       158
# 14698       140
# 14570       109
# 11193        97
# 11042        96
# 13264        91
# 12191        76
# ...

# %%
y=d_flights['DEST_AIRPORT_ID']
y.value_counts()
# Out:
# 14747    137161
# 11884     11677
# 12892     10186
# 14771      9746
# 11292      8743
# 12889      7312
# 10299      6829
# 14869      6369
# 14107      6119
# 13930      5241
# 14057      4572
# 14893      4453
# 13487      4290
# 13796      4172
# 11298      4127
# 14831      3922
# 14679      3832
# 14252      3808
# 10713      3237
# 10397      3126
# 12478      2637
# 12266      2491
# 14908      2480
# 11433      2313
# 10721      2076
# 11618      1930
# 12173      1721
# 11630      1701
# 13830      1440
# 12819      1385
#           ...
# 14492       560
# 15376       493
# 13303       463
# 11697       451
# 14489       378
# 10140       365
# 13495       365
# 14683       365
# 15304       365
# 13871       364
# 14689       292
# 13851       255
# 10849       238
# 12339       235
# 10994       209
# 14828       206
# 11109       165
# 12278       158
# 14698       140
# 14570       120
# 11042        97
# 11193        94
# 13264        92
# 12191        76
# ...

# %%
y=d_flights['CRS_DEP_TIME']
y.value_counts()
# Out:
# 600     6566
# 700     4326
# 800     3828
# 1000    2271
# 1700    2102
# 740     2095
# 1345    2086
# 1115    2024
# 630     1988
# 1140    1962
# 1855    1952
# 1955    1936
# 730     1934
# 1145    1897
# 1940    1809
# 1850    1802
# 745     1793
# 715     1786
# 815     1747
# 1200    1704
# 1515    1679
# 1025    1672
# 620     1649
# 820     1633
# 1100    1626
# 605     1612
# 1530    1600
# 500     1558
# 1755    1549
# 930     1543
#         ...
# 821        1
# 731        1
# 235        1
# 7          1
# 1806       1
# 607        1
# 2108       1
# 2122       1
# 2342       1
# 2004       1
# 58         1
# 2127       1
# 1628       1
# 1157       1
# 1204       1
# 33         1
# 2336       1
# 2147       1
# 904        1
# 2113       1
# 529        1
# 2339       1
# 823        1
# 2323       1
# 546        1
# 2043       1
# 2144       1
# 1456       1
# 2003       1
# 846        1
# Name: CRS_DEP_TIME, Length: 1092, dtype: int64

# %%
y=d_flights['CRS_ARR_TIME']
y.value_counts()
# Out:
# 1100    1222
# 1045    1214
# 2200    1187
# 2035    1094
# 905     1089
# 1430    1086
# 1945    1044
# 900     1016
# 845     1008
# 2230     991
# 850      946
# 1700     915
# 1605     893
# 1440     889
# 1610     884
# 1740     869
# 1425     858
# 1745     853
# 2020     848
# 2359     846
# 1400     837
# 1955     830
# 1840     829
# 855      816
# 1315     813
# 1810     808
# 1640     805
# 1625     790
# 1255     788
# 1235     768
#         ...
# 38         4
# 143        4
# 106        3
# 58         2
# 306        2
# 317        2
# 247        2
# 337        1
# 140        1
# 333        1
# 404        1
# 427        1
# 405        1
# 126        1
# 129        1
# 408        1
# 246        1
# 311        1
# 346        1
# 245        1
# 154        1
# 315        1
# 128        1
# 101        1
# 51         1
# 439        1
# 316        1
# 240        1
# 436        1
# 536        1
# Name: CRS_ARR_TIME, Length: 1340, dtype: int64

# %%
y=d_flights['CRS_ELAPSED_TIME']
y.value_counts()
# Out:
# 125    5944
# 160    5757
# 130    5116
# 165    4853
# 155    4157
# 120    4134
# 170    3950
# 115    3430
# 135    3255
# 180    2895
# 175    2862
# 140    2776
# 163    2718
# 110    2579
# 162    2406
# 164    2369
# 158    2325
# 157    2253
# 150    2239
# 168    2166
# 124    2138
# 60     2034
# 131    1938
# 129    1909
# 167    1887
# 166    1882
# 154    1877
# 156    1864
# 145    1854
# 123    1853
#        ...
# 372     162
# 337     161
# 78      155
# 91      151
# 405     143
# 393     115
# 85      100
# 359      92
# 411      88
# 403      82
# 399      71
# 42       64
# 40       62
# 41       62
# 402      53
# 410      43
# 407      42
# 409      40
# 81       38
# 413      37
# 404      36
# 414      34
# 401      31
# 416      17
# 419       9
# 86        9
# 406       8
# 415       2
# 38        1
# 34        1
# Name: CRS_ELAPSED_TIME, Length: 378, dtype: int64

# %%
print d_flights.shape
# Out:
# (296571, 11)

# %%
for col in d_flights.columns:
    if (d_flights[col].dtype.name == 'object'):
        print d_flights[col].value_counts(), '\n'

# %%
for col in d_flights.columns:
    if (d_flights[col].dtype.name == 'category'):
        print d_flights[col].value_counts(), '\n'
# Out:
# AS    117668
# DL     46402
# OO     45627
# WN     31187
# UA     21159
# AA     19345
# VX      4460
# B6      3971
# NK      3588
# F9      1685
# HA      1479
# Name: UNIQUE_CARRIER, dtype: int64

# %%
for col in d_flights.columns:
    if (d_flights[col].dtype.name in ['category', 'str', 'object']):
        # 4. Check for extra whitespaces and remove them
        d_flights[col] = d_flights[col].str.strip()
        # 5. Cast text to lower-case
        d_flights[col] = d_flights[col].str.lower()

# %%
d_flights.describe()
# Out:
#                MONTH   DAY_OF_MONTH    DAY_OF_WEEK  ORIGIN_AIRPORT_ID  \
# count  296571.000000  296571.000000  296571.000000      296571.000000
# mean        6.676573      15.793436       3.960209       13757.276325
# std         3.332504       8.783396       1.995942        1429.142132
# min         1.000000       1.000000       1.000000       10140.000000
# 25%         4.000000       8.000000       2.000000       12889.000000
# 50%         7.000000      16.000000       4.000000       14747.000000
# 75%         9.000000      23.000000       6.000000       14747.000000
# max        12.000000      31.000000       7.000000       15389.000000
#
#        DEST_AIRPORT_ID   CRS_DEP_TIME   CRS_ARR_TIME      ARR_DELAY  \
# count    296571.000000  296571.000000  296571.000000  293975.000000
# mean      13754.070293    1326.744813    1497.350473       2.227111
# std        1431.886797     525.349760     551.789906      37.033987
# ...

# %%
d_flights['ARR_DELAY'].unique()
# Out:
# array([-9.000e+00,  3.700e+01,  3.050e+02,  0.000e+00, -2.500e+01,
#        -1.000e+01, -1.900e+01, -5.000e+00, -3.500e+01,  3.900e+01,
#         2.000e+00, -2.000e+00,  1.000e+01, -2.200e+01, -4.000e+00,
#        -1.500e+01, -1.200e+01, -2.000e+01, -3.100e+01,  9.000e+00,
#         1.300e+01,  3.500e+01,  1.500e+01,  2.000e+01,  4.000e+01,
#         6.900e+01, -7.000e+00, -1.100e+01, -6.000e+00, -1.600e+01,
#        -3.600e+01, -1.300e+01, -3.000e+00, -8.000e+00, -1.400e+01,
#         4.400e+01,  2.100e+01, -1.700e+01,  2.600e+01, -2.800e+01,
#        -2.900e+01, -4.900e+01, -5.300e+01,  1.400e+02,  8.000e+00,
#         1.420e+02,  7.800e+01,  1.800e+01,  2.400e+01,  3.000e+00,
#        -1.000e+00,  7.000e+00,  1.000e+00,  1.100e+01, -2.100e+01,
#        -5.500e+01,  2.200e+01,  1.400e+01,  1.700e+01,  1.900e+01,
#         4.000e+00, -2.400e+01,  5.000e+00,  8.600e+01, -1.800e+01,
#         9.400e+01,  8.300e+01,  1.200e+01,  6.000e+00,        nan,
# ...

# %%
d_flights.isnull().sum()
# Out:
# MONTH                   0
# DAY_OF_MONTH            0
# DAY_OF_WEEK             0
# UNIQUE_CARRIER          0
# ORIGIN_AIRPORT_ID       0
# DEST_AIRPORT_ID         0
# CRS_DEP_TIME            0
# CRS_ARR_TIME            0
# ARR_DELAY            2596
# CRS_ELAPSED_TIME        0
# DISTANCE                0
# dtype: int64

# %%
d_flights[d_flights.ARR_DELAY.isnull()].head()
# Out:
#       MONTH  DAY_OF_MONTH  DAY_OF_WEEK UNIQUE_CARRIER  ORIGIN_AIRPORT_ID  \
# 159       1            15            7             AA              14747
# 305       1             2            1             DL              14747
# 1061      1             5            4             F9              11292
# 1062      1             5            4             F9              14747
# 1318      1             9            1             OO              11884
#
#       DEST_AIRPORT_ID  CRS_DEP_TIME  CRS_ARR_TIME  ARR_DELAY  \
# 159             11298          1342          1929        NaN
# 305             13830          1215          1654        NaN
# 1061            14747           715           925        NaN
# 1062            11292          1010          1354        NaN
# 1318            12892           710          1015        NaN
#
#       CRS_ELAPSED_TIME  DISTANCE
# 159                227      1660
# 305                399      2640
# 1061               190      1024
# ...

# %%
d_flights.dropna(axis=0, how='any', inplace=True)

# %%
d_flights.isnull().sum()
# Out:
# MONTH                0
# DAY_OF_MONTH         0
# DAY_OF_WEEK          0
# UNIQUE_CARRIER       0
# ORIGIN_AIRPORT_ID    0
# DEST_AIRPORT_ID      0
# CRS_DEP_TIME         0
# CRS_ARR_TIME         0
# ARR_DELAY            0
# CRS_ELAPSED_TIME     0
# DISTANCE             0
# dtype: int64

# %%
##Exploratory Data Analysis

# %%
#Visualization for 11 columns

# %%
import matplotlib.pyplot as plt

# %%
d_flights['MONTH'].value_counts().plot(kind='bar')
plt.title('MONTH\n')
plt.xlabel('MONTH')
plt.ylabel('frequency')
plt.legend(['Months of the year: Jan-Dec'])
plt.show()

# %%
# Most of the flights are in Augus.

# %%
d_flights['DAY_OF_MONTH'].value_counts().plot(kind='bar')
plt.title('Day of Month\n')
plt.xlabel('DAY_OF_MONTH')
plt.ylabel('frequency')
plt.legend(['Days of months: 1-31'])
plt.show()

# %%
# Most of flights are in the middle to end of month

# %%
d_flights['DAY_OF_WEEK'].value_counts().plot(kind='pie')
plt.title('Frequency of flights during days of Week\n')
plt.xlabel('DAY_OF_WEEK')
plt.ylabel('frequency')
plt.legend(['Day of week, Mon:1 - Sun:7'])
plt.show()

# %%
d_flights['UNIQUE_CARRIER'].value_counts().plot(kind='bar')
plt.title('Airlines: Alaska,Delta,Skywest,United,American,Virgin,Jetblue,spirit,Frontier,Hawaiian\n')
plt.xlabel('UNIQUE_CARRIER')
plt.ylabel('frequency')
plt.legend(['Airlines'])
plt.show()

# %%
# Majorarity of the flights belong to 'AS=Alaska'

# %%
d_flights['ORIGIN_AIRPORT_ID'].value_counts().plot(kind='pie')
plt.title('ORIGIN_AIRPORT\n')
plt.xlabel('Origin Airport')
plt.ylabel('frequency')
plt.legend(['Origin Airports'])
plt.show()

# %%
# Finding name of an airport by using the code
# As we can see in destinations and origin airports plots,Code14747 is origin and destination of many flights
Arcode=14747
Arcode_mask=Airport['Code']==Arcode
ArptNameDest=Airport.loc[Arcode_mask,'Description']
ArptNameDest
# Out:
# 4525    Seattle, WA: Seattle/Tacoma International
# Name: Description, dtype: object

# %%
d_flights['DEST_AIRPORT_ID'].value_counts().plot(kind='pie')
plt.title('Destination Airports\n')
plt.xlabel('Destination Airport')
plt.ylabel('frequency')
plt.legend(['Destination Airport'])
plt.show()

# %%
d_flights['CRS_DEP_TIME'].plot(kind='hist')
plt.title('CRS Departure Time(local time:hhmm)\n')
plt.xlabel('CRS Departure Time')
plt.ylabel('frequency')
plt.legend(['CRS Departure Time'])
plt.show()

# %%
d_flights['CRS_ARR_TIME'].value_counts().plot(kind='hist')
plt.title('CRS Arrival Time(local time:hhmm)\n')
plt.xlabel('CRS Arrival Time')
plt.ylabel('frequency')
plt.legend(['CRS Arrival Time'])
plt.show()

# %%
d_flights['ARR_DELAY'].plot(kind='density')
plt.title('Flights Arrival Delay (minutes)\n')
plt.xlabel('Arr Delay_Early arrival:negative')
plt.ylabel('density')
plt.legend(['Flights Arrival Delay'])
plt.show()

# %%
d_flights['DISTANCE'].plot(kind='hist')
plt.title('Distance between Airports(miles) _ \n')
plt.xlabel('Distance')
plt.ylabel('density')
plt.legend(['Distance'])
plt.show()

# %%
d_flights['CRS_ELAPSED_TIME'].plot(kind='box')
plt.title('CRS_ELAPSED_TIME\n')
plt.xlabel('CRS_ELAPSED_TIME')
plt.ylabel('frequency')
plt.legend(['CRS Elapsed Time of Flight, in Minutes'])
plt.show()

# %%
d_flights['CRS_ELAPSED_TIME'].plot(kind='bar')
plt.title('CRS_ELAPSED_TIME\n')
plt.xlabel('CRS_ELAPSED_TIME')
plt.ylabel('frequency')
plt.legend(['CRS Elapsed Time of Flight, in Minutes'])
plt.show()

# %%
# Exploring the relationship between columns

# %%
d_flights.plot(kind='scatter', x='DISTANCE', y='ARR_DELAY')
plt.title('Relation between Flight Distance and Arrival Delay\n')
plt.xlabel('DISTANCE')
plt.ylabel('ARR_DELAY')
plt.legend(['DISTANCE/ARR_DELAY'])
plt.show()

# %%
d_flights.plot(kind='scatter', x='DISTANCE', y='CRS_ELAPSED_TIME')
plt.title('Relation between Flight Distance and Departure Delay\n')
plt.xlabel('DISTANCE')
plt.ylabel('CRS_ELAPSED_TIME')
plt.legend(['DISTANCE/CRS_ELAPSED_TIME'])
plt.show()

# %%
d_flights.plot(kind='scatter', x='CRS_ELAPSED_TIME', y='ARR_DELAY')
plt.title('relationship between Elapsed Time and Arrival Delay\n')
plt.xlabel('CRS_ELAPSED_TIME')
plt.ylabel('ARR_DELAY')
plt.legend(['CRS_ELAPSED_TIME/ARR_DELAY'])
plt.show()

# %%
# In this graph we can easily understand that most of the flights have delay by 2.50 hours.

# %%
d_flights.plot(kind='scatter', x='MONTH', y='ARR_DELAY')
plt.title('relationship between Month of flight and Arrival Delay\n')
plt.xlabel('Month')
plt.ylabel('ARR_DELAY')
plt.legend(['Month/ARR_DELAY'])
plt.show()

# %%
# The delay is quite more in November and February(start of spring and travels)

# %%
d_flights.plot(kind='scatter', x='DAY_OF_MONTH', y='ARR_DELAY')
plt.title('relationship between DAY_OF_MONTH and Arrival Delay\n')
plt.xlabel('DAY_OF_MONTH')
plt.ylabel('ARR_DELAY')
plt.legend(['DAY_OF_MONTH/ARR_DELAY'])
plt.show()

# %%
#Maximum delays are at 3rd, 7th, 18th, 26th and 29th of the month

# %%
#Bar Charts may be better

# %%
d_flights.plot(kind='scatter', x='DAY_OF_WEEK', y='ARR_DELAY')
plt.title('relationship between DAY_OF_WEEK and Arrival Delay\n')
plt.xlabel('DAY_OF_WEEK')
plt.ylabel('ARR_DELAY')
plt.legend(['DAY_OF_WEEK/ARR_DELAY'])
plt.show()

# %%
d_flights.plot(kind='scatter', x='ORIGIN_AIRPORT_ID', y='ARR_DELAY')
plt.title('relationship between Origin Airport and Arrival Delay\n')
plt.xlabel('Origin Airport')
plt.ylabel('ARR_DELAY')
plt.legend(['Origin Airport/ARR_DELAY'])
plt.show()

# %%
d_flights.plot(kind='scatter', x='DEST_AIRPORT_ID', y='ARR_DELAY')
plt.title('relationship between Destination Airport and Arrival Delay\n')
plt.xlabel('Destination Airport')
plt.ylabel('ARR_DELAY')
plt.legend(['Destination Airport/ARR_DELAY'])
plt.show()

# %%
d_flights.plot(kind='scatter', x='CRS_DEP_TIME', y='ARR_DELAY')
plt.title('relationship between Departure Time and Arrival Delay\n')
plt.xlabel('Departure Time')
plt.ylabel('ARR_DELAY')
plt.legend(['Departure Time/ARR_DELAY'])
plt.show()

# %%
#most of the delays ar for flights departing around 8am, noon, 10am

# %% [markdown]
# d_flights.plot(kind='scatter', x='CRS_ARR_TIME', y='ARR_DELAY')
# plt.title('relationship between Arrival Time and Arrival Delay\n')
# plt.xlabel('Arrival Time ')
# plt.ylabel('ARR_DELAY')
# plt.legend('')
# plt.show()

# %%
# In this graph we can easily understand most of the delays are around3pm, midnight, 10am

# %%
d_flights.plot(kind='scatter', x='DISTANCE', y='CRS_ARR_TIME')
plt.title('relationship between Distance of Flight and Arrival Time\n')
plt.xlabel('Distance of Flight')
plt.ylabel('Arrival Time')
plt.legend(['Distance/Arrival Time'])
plt.show()

# %%
d_flights.plot(kind='scatter', x='DISTANCE', y='CRS_DEP_TIME')
plt.title('relationship between Distance of Flight and Departure Time\n')
plt.xlabel('Distance of Flight')
plt.ylabel('Departure Time')
plt.legend(['Distance/Departure Time'])
plt.show()

# %%
d_flights.plot(kind='scatter', x='DISTANCE', y='ORIGIN_AIRPORT_ID')
plt.title('relationship between Distance of Flight and Origin Airport\n')
plt.xlabel('Distance of Flight')
plt.ylabel('Origin Airport')
plt.legend(['Distance/Origin Airport'])
plt.show()

# %%
d_flights.plot(kind='scatter', x='DISTANCE', y='DEST_AIRPORT_ID')
plt.title('relationship between Distance of Flight and Destination Airport\n')
plt.xlabel('Distance of Flight')
plt.ylabel('Destination Airport')
plt.legend(['Distance of Flight/Destination Airport'])
plt.show()

# %%
d_flights.plot(kind='scatter', x='DAY_OF_WEEK', y='ORIGIN_AIRPORT_ID')
plt.title('relation between Day of Week and Origin Airport\n')
plt.xlabel('Day of Week')
plt.ylabel('Origin Airport')
plt.legend(['Day of Week/Origin Airport'])
plt.show()

# %%
d_flights.plot(kind='scatter', x='DAY_OF_WEEK', y='DEST_AIRPORT_ID')
plt.title('relation between Day of Week and Destination Airport\n')
plt.xlabel('Day of Week')
plt.ylabel('Destination Airport')
plt.legend(['Day of Week/Destination Airport'])
plt.show()

# %%
d_flights.plot(kind='scatter', x='MONTH', y='ORIGIN_AIRPORT_ID')
plt.title('relation between Month of Flight and Origin Airport\n')
plt.xlabel('Month of Flight ')
plt.ylabel('Origin Airport')
plt.legend(['Month of Flight/Origin Airport'])
plt.show()

# %%
d_flights.plot(kind='scatter', x='MONTH', y='DEST_AIRPORT_ID')
plt.title('relation between Month of Flight and Destination Airport\n')
plt.xlabel('Month of Flight ')
plt.ylabel('Destination Airport')
plt.legend(['Month of Flight/Destination Airport'])
plt.show()

# %%
d_flights.plot(kind='scatter', x='DAY_OF_MONTH', y='CRS_DEP_TIME')
plt.title('relation between Day of Month of Flight and Departure Time\n')
plt.xlabel('Day of Month')
plt.ylabel('Departure Time')
plt.legend(['Day of Month/DepartureTime'])
plt.show()

# %%
d_flights.plot(kind='scatter', x='DAY_OF_MONTH', y='CRS_ARR_TIME')
plt.title('relation between Day of Month of Flight and Arrival Time\n')
plt.xlabel('Day of Month')
plt.ylabel('Arrival Time')
plt.legend(['Day of Month/Arrival Time'])
plt.show()

# %%
#Scatter Matrix of all Numeric Columns

# %%
from pandas.plotting import scatter_matrix

# %%
# import pandas.plotting.scatter_matrix

# %%
scatter_matrix(d_flights,alpha=0.2,figsize=(5,5),diagonal='hist')
plt.suptitle('Scatter matrix for all numerical columns')
plt.show()

# %%
scatter_matrix(d_flights,alpha=0.2,figsize=(16,16),diagonal='hist')
plt.suptitle('Scatter matrix for all numerical columns')
plt.show()

# %%
# Droping minutes from departure and arrival times

# %%
d_flights['CRS_DEP_TIME']=(d_flights['CRS_DEP_TIME']/100).round()
d_flights['CRS_DEP_TIME']=d_flights['CRS_DEP_TIME'].astype(int)
d_flights['CRS_DEP_TIME'].value_counts()
# Out:
# 6     22256
# 7     20650
# 8     19724
# 11    19252
# 10    18880
# 17    18338
# 15    18157
# 19    17784
# 18    16568
# 13    15799
# 12    15714
# 14    14780
# 9     14089
# 20    13574
# 16    12488
# 21     9341
# 22     9289
# 23     6279
# 5      5682
# 0      2342
# 24     1359
# 1      1268
# 2       350
# 3        12
# Name: CRS_DEP_TIME, dtype: int64

# %%
#d_flights['CRS_ARR_TIME'].value_counts()
d_flights['CRS_ARR_TIME']=(d_flights['CRS_ARR_TIME']/100).round()
d_flights['CRS_ARR_TIME']=d_flights['CRS_ARR_TIME'].astype(int)
d_flights['CRS_ARR_TIME'].value_counts()
# Out:
# 16    24094
# 22    20089
# 14    19651
# 20    19615
# 12    18960
# 18    18957
# 21    18178
# 10    17663
# 9     15639
# 13    14393
# 17    13865
# 19    13770
# 23    13350
# 8     12782
# 11    11817
# 15    10872
# 6      7014
# 7      6661
# 0      4891
# 24     4131
# 5      3679
# 2      1610
# 1      1406
# 4       784
# 3       104
# Name: CRS_ARR_TIME, dtype: int64

# %%
# Carrier - Changing Alphabetic Code to numeric code
Carrier=pd.read_csv("Carrier_Lookup.csv",header=0)
Carrier.dtypes
Carrier
# Out:
#         Code                                        Description
# 0        02Q                                      Titan Airways
# 1        04Q                                 Tradewind Aviation
# 2        05Q                                Comlux Aviation, AG
# 3        06Q                      Master Top Linhas Aereas Ltd.
# 4        07Q                                Flair Airlines Ltd.
# 5        09Q                                     Swift Air, LLC
# 6        0BQ                                                DCA
# 7        0CQ                               ACM AIR CHARTER GmbH
# 8        0GQ       Inter Island Airways, d/b/a Inter Island Air
# 9        0HQ            Polar Airlines de Mexico d/b/a Nova Air
# 10        0J                                         JetClub AG
# 11       0JQ                                    Vision Airlines
# 12       0LQ                                  Metropix UK, LLP.
# 13       0MQ              Multi-Aero, Inc. d/b/a Air Choice One
# ...

# %%
d_flights['UNIQUE_CARRIER'].value_counts()
# Out:
# as    116625
# dl     46251
# oo     45041
# wn     31022
# ua     20954
# aa     19115
# vx      4393
# b6      3914
# nk      3511
# f9      1674
# ha      1475
# Name: UNIQUE_CARRIER, dtype: int64

# %%
Carrier.isnull().sum()
# Out:
# Code           1
# Description    0
# dtype: int64

# %%
Carrier.dropna(axis=0, how='any', inplace=True)

# %%
Carrier.isnull().sum()
# Out:
# Code           0
# Description    0
# dtype: int64

# %%
#Replace CarrierUniqIDr(characters) with Carrier codes(Numbers)
d_flights['UNIQUE_CARRIER'].replace('AS', '3', inplace=True)
d_flights['UNIQUE_CARRIER'].replace('DL', '5', inplace=True)
d_flights['UNIQUE_CARRIER'].replace('WN', '15', inplace=True)
d_flights['UNIQUE_CARRIER'].replace('OO', '11', inplace=True)
d_flights['UNIQUE_CARRIER'].replace('UA', '12', inplace=True)
d_flights['UNIQUE_CARRIER'].replace('AA', '2', inplace=True)
d_flights['UNIQUE_CARRIER'].replace('VX', '14', inplace=True)
d_flights['UNIQUE_CARRIER'].replace('B6', '4', inplace=True)
d_flights['UNIQUE_CARRIER'].replace('NK', '1', inplace=True)
d_flights['UNIQUE_CARRIER'].replace('F9', '7', inplace=True)
d_flights['UNIQUE_CARRIER'].replace('HA', '9', inplace=True)

# %%
d_flights['UNIQUE_CARRIER'].value_counts()
# Out:
# 3     116625
# 5      46251
# 11     45041
# 15     31022
# 12     20954
# 2      19115
# 14      4393
# 4       3914
# 1       3511
# 7       1674
# 9       1475
# Name: UNIQUE_CARRIER, dtype: int64

# %%
#    M O D E L L I N G

# %%
# All columns numeric

# %%
d_flights['DISTANCE']=d_flights[['DISTANCE']].astype('float')
d_flights['UNIQUE_CARRIER'] = d_flights['UNIQUE_CARRIER'].astype('int64')
d_flights['ORIGIN_AIRPORT_ID'] = d_flights['ORIGIN_AIRPORT_ID'].astype('int64')
d_flights['DEST_AIRPORT_ID'] = d_flights['DEST_AIRPORT_ID'].astype('int64')
d_flights['CRS_DEP_TIME'] = d_flights['CRS_DEP_TIME'].astype('int64')
d_flights['CRS_ARR_TIME'] = d_flights['CRS_ARR_TIME'].astype('int64')
d_flights['ARR_DELAY'] = d_flights['ARR_DELAY'].astype('int64')
d_flights['MONTH'] = d_flights['MONTH'].astype('int64')
d_flights['DAY_OF_MONTH'] = d_flights['DAY_OF_MONTH'].astype('int64')
d_flights['DAY_OF_WEEK'] = d_flights['DAY_OF_WEEK'].astype('int64')
d_flights['CRS_ELAPSED_TIME'] = d_flights['CRS_ELAPSED_TIME'].astype('int64')

# %%
# Feature Selection Using Hill Climbing
# Usually it takes time

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.utils import shuffle

# %%
col_num=10
new_Ind=[]
cur_MaxScore=0.0
col_Ind_Random=shuffle(range(0, col_num), random_state=1)

# %%
y=d_flights['ARR_DELAY'].values
X=d_flights[[ 'MONTH','DAY_OF_MONTH', 'DAY_OF_WEEK', 'UNIQUE_CARRIER', 'ORIGIN_AIRPORT_ID', 'DEST_AIRPORT_ID',  'CRS_DEP_TIME',
          'CRS_ARR_TIME', 'CRS_ELAPSED_TIME', 'DISTANCE']]

# %%
for cur_f in range(0, col_num):
    new_Ind.append(col_Ind_Random[cur_f])
    newData = X.iloc[:, new_Ind]
    X_train, X_test, y_train, y_test = train_test_split(newData,
    y, test_size=0.4, random_state=0)
    clf = KNeighborsClassifier(5, weights='distance', p=1)
    fit = clf.fit(X_train, y_train)
    cur_Score = clf.score(X_test, y_test)
    if cur_Score < cur_MaxScore:
        new_Ind.remove(col_Ind_Random[cur_f])
    else:
        cur_MaxScore = cur_Score
        print "Score with " + str(len(new_Ind)) + " selected  features: " + str(cur_Score)

# %%
#Changing the order of columns

# %%
col_num=8
new_Ind=[]
cur_MaxScore=0.0
col_Ind_Random=shuffle(range(0, col_num), random_state=1)

# %%
y=d_flights['ARR_DELAY'].values

# %%
X=d_flights[[ 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'ORIGIN_AIRPORT_ID', 'DEST_AIRPORT_ID', 'CRS_ARR_TIME', 'CRS_DEP_TIME', 
                   'UNIQUE_CARRIER', 'DISTANCE']]

# %%
for cur_f in range(0, col_num):
    new_Ind.append(col_Ind_Random[cur_f])
    newData = X.iloc[:, new_Ind]
    X_train, X_test, y_train, y_test = train_test_split(newData,
    y, test_size=0.4, random_state=0)
    clf = KNeighborsClassifier(5, weights='distance', p=1)
    fit = clf.fit(X_train, y_train)
    cur_Score = clf.score(X_test, y_test)
    if cur_Score < cur_MaxScore:
        new_Ind.remove(col_Ind_Random[cur_f])
    else:
        cur_MaxScore = cur_Score
        print "Score with " + str(len(new_Ind)) + " selected  features: " + str(cur_Score)

# %%
#Some information about flights and routs

# %%
#Airport Lookup Table
Airport=pd.read_csv("Airport_Lookup.csv",header=0)
Airport.head()
# Out:
#        Code                                        Description
# 0     10001             Afognak Lake, AK: Afognak Lake Airport
# 1     10003      Granite Mountain, AK: Bear Creek Mining Strip
# 2     10004                           Lik, AK: Lik Mining Camp
# 3     10005             Little Squaw, AK: Little Squaw Airport
# 4     10006                         Kizhuyak, AK: Kizhuyak Bay
# 5     10007                 Klawock, AK: Klawock Seaplane Base
# 6     10008     Elizabeth Island, AK: Elizabeth Island Airport
# 7     10009                         Homer, AK: Augustin Island
# 8     10010                        Hudson, NY: Columbia County
# 9     10011               Peach Springs, AZ: Grand Canyon West
# 10    10012                 Blairstown, NJ: Blairstown Airport
# 11    10013                 Crosbyton, TX: Crosbyton Municipal
# 12    10014           Fairbanks/Ft. Wainwright, AK: Blair Lake
# 13    10015             Deadmans Bay, AK: Deadmans Bay Airport
# ...

# %%
#Filter for  origin CityName

# %%
mask_City=Airport['Description'].str.contains("Chicago")

# %%
Airport.loc[mask_City, 'Description']
# Out:
# 942                         Chicago, IL: Meigs Field
# 951           Chicago, IL: Chicago Metropolitan Area
# 1321                     Chicago, IL: Du Page County
# 1974            Gary, IN: Gary/Chicago International
# 2215        Chicago/Romeoville, IL: Lewis University
# 3098       Chicago, IL: Chicago Midway International
# 3770       Chicago, IL: Chicago O'Hare International
# 4151                  Chicago, IL: Chicago Executive
# 4295    Rockford, IL: Chicago/Rockford International
# Name: Description, dtype: object

# %%
City_Filter=Airport[mask_City]

# %%
City_Filter
# Out:
#        Code                                   Description
# 942   10977                      Chicago, IL: Meigs Field
# 951   10986        Chicago, IL: Chicago Metropolitan Area
# 1321  11376                   Chicago, IL: Du Page County
# 1974  12055          Gary, IN: Gary/Chicago International
# 2215  12306      Chicago/Romeoville, IL: Lewis University
# 3098  13232     Chicago, IL: Chicago Midway International
# 3770  13930     Chicago, IL: Chicago O'Hare International
# 4151  14320                Chicago, IL: Chicago Executive
# 4295  14512  Rockford, IL: Chicago/Rockford International

# %%
# Flights for O'Hre Airport

# %%
Airport_mask=Airport['Description'].str.contains("O'\Hare")

# %%
Airport.loc[Airport_mask, 'Description']
# Out:
# 3770    Chicago, IL: Chicago O'Hare International
# Name: Description, dtype: object

# %%
AirportCode=Airport.loc[Airport_mask, 'Code'].unique()

# %%
AirportCode[0]
# Out:
# 13930

# %%
#print(len(d_flights['ORIGIN_AIRPORT_ID'].unique()))
# Out:
# 83

# %%
Airport_mask1=d_flights['ORIGIN_AIRPORT_ID']==AirportCode[0]

# %%
Origin_airport=d_flights[Airport_mask1]

# %%
Origin_airport.head()
# Out:
#       MONTH  DAY_OF_MONTH  DAY_OF_WEEK UNIQUE_CARRIER  ORIGIN_AIRPORT_ID  \
# 2220      1            27            5             UA              13930
# 2236      1            26            4             UA              13930
# 2250      1            26            4             UA              13930
# 2260      1            26            4             UA              13930
# 2275      1            25            3             UA              13930
#
#       DEST_AIRPORT_ID  CRS_DEP_TIME  CRS_ARR_TIME  ARR_DELAY  \
# 2220            14747          1651          1929      -16.0
# 2236            14747          1945          2225      -21.0
# 2250            14747           915          1152      -37.0
# 2260            14747          1651          1929      -34.0
# 2275            14747          1945          2225      -39.0
#
#       CRS_ELAPSED_TIME  DISTANCE
# 2220               278      1721
# 2236               280      1721
# 2250               277      1721
# ...

# %%
# Finding name of an airport by using the code
# As we can see in destinations and origin airports plots,Code14747 is origin and destination of many flights

# %%
Arcode=14747

# %%
Arcode_mask=Airport['Code']==Arcode

# %%
ArptNameDest=Airport.loc[Arcode_mask,'Description']

# %%
ArptNameDest
# Out:
# 4525    Seattle, WA: Seattle/Tacoma International
# Name: Description, dtype: object

# %%
#ArptNameDest['Description'][Arcode_mask]

# %%
DestArptName=Airport.loc[4525,'Description']

# %%
DestArptName
# Out:
# 'Seattle, WA: Seattle/Tacoma International'

# %%
#finding flights departing from O'Hare

# %%
flight_mask1=d_flights['ORIGIN_AIRPORT_ID']==13930

# %%
route_1=d_flights.loc[flight_mask1]

# %%
route_1.head()

# %%
# Flights for Destination Airport

# %%
Airport_mask2=Airport['Description'].str.contains("Boston, MA: Logan International")

# %%
Airport.loc[Airport_mask2, 'Description']
# Out:
# 693    Boston, MA: Logan International
# Name: Description, dtype: object

# %%
# Finding another busy route

# %%
AirportCode2=Airport.loc[Airport_mask2, 'Code'].unique()

# %%
AirportCode2
# Out:
# array([10721], dtype=int64)

# %%
Airport_mask2=d_flights['ORIGIN_AIRPORT_ID']==AirportCode2[0]

# %%
Destination_airport=d_flights[Airport_mask2]

# %%
Destination_airport.head()
# Out:
#      MONTH  DAY_OF_MONTH  DAY_OF_WEEK UNIQUE_CARRIER  ORIGIN_AIRPORT_ID  \
# 205      1             1            7             DL              10721
# 297      1             2            1             DL              10721
# 362      1            11            3             DL              10721
# 453      1            12            4             DL              10721
# 549      1            13            5             DL              10721
#
#      DEST_AIRPORT_ID  CRS_DEP_TIME  CRS_ARR_TIME  ARR_DELAY  CRS_ELAPSED_TIME  \
# 205            14747           700          1031       39.0               391
# 297            14747           700          1032      609.0               392
# 362            14747           710          1042       29.0               392
# 453            14747           710          1042       -3.0               392
# 549            14747           710          1042       19.0               392
#
#      DISTANCE
# 205      2496
# 297      2496
# 362      2496
# ...

# %%
Destination_airport.describe()
# Out:
#              MONTH  DAY_OF_MONTH  DAY_OF_WEEK  ORIGIN_AIRPORT_ID  \
# count  2075.000000   2075.000000  2075.000000             2075.0
# mean      6.781205     15.909880     4.014458            10721.0
# std       3.163396      8.762156     2.012206                0.0
# min       1.000000      1.000000     1.000000            10721.0
# 25%       4.000000      8.000000     2.000000            10721.0
# 50%       7.000000     16.000000     4.000000            10721.0
# 75%       9.000000     23.000000     6.000000            10721.0
# max      12.000000     31.000000     7.000000            10721.0
#
#        DEST_AIRPORT_ID  CRS_DEP_TIME  CRS_ARR_TIME    ARR_DELAY  \
# count           2075.0   2075.000000   2075.000000  2039.000000
# mean           14747.0   1210.087229   1546.220241     1.953899
# std                0.0    535.399122    549.125870    43.333914
# min            14747.0    644.000000    952.000000   -76.000000
# ...

# %%
# Finding flights  for a route(from O'hare Airport to Logan International) 
# Filter for the route

# %%
#Airport_mask_route1=(d_flights['ORIGIN_AIRPORT_ID']==AirportCode[0]) & (d_flights['DEST_AIRPORT_ID']==AirportCode2[0])

# %%
Airport_mask_route1=d_flights['DEST_AIRPORT_ID']==14747

# %%
Route_1=d_flights[Airport_mask_route1]

# %%
Route_1.head()
# Out:
#     MONTH  DAY_OF_MONTH  DAY_OF_WEEK  UNIQUE_CARRIER  ORIGIN_AIRPORT_ID  \
# 0       1             1            7               2              14100
# 1       1             2            1               2              14100
# 13      1             9            1               2              12892
# 14      1            10            2               2              12892
# 15      1            11            3               2              12892
#
#     DEST_AIRPORT_ID  CRS_DEP_TIME  CRS_ARR_TIME  ARR_DELAY  CRS_ELAPSED_TIME  \
# 0             14747            20            24         -9               365
# 1             14747            20            24         37               365
# 13            14747            16            19          0               173
# 14            14747            16            19         10               173
# 15            14747            16            19        -22               173
#
#     DISTANCE
# 0     2378.0
# 1     2378.0
# 13     954.0
# ...

# %%
Route_1.describe()
# Out:
#                MONTH   DAY_OF_MONTH    DAY_OF_WEEK  UNIQUE_CARRIER  \
# count  135918.000000  135918.000000  135918.000000   135918.000000
# mean        6.669462      15.816514       3.959225        6.280044
# std         3.323082       8.781148       1.995330        4.424157
# min         1.000000       1.000000       1.000000        1.000000
# 25%         4.000000       8.000000       2.000000        3.000000
# 50%         7.000000      16.000000       4.000000        3.000000
# 75%         9.000000      23.000000       6.000000       11.000000
# max        12.000000      31.000000       7.000000       15.000000
#
#        ORIGIN_AIRPORT_ID  DEST_AIRPORT_ID   CRS_DEP_TIME   CRS_ARR_TIME  \
# count      135918.000000         135918.0  135918.000000  135918.000000
# mean        12912.594020          14747.0      13.245817      14.781758
# std          1518.440662              0.0       5.180072       5.570296
# min         10140.000000          14747.0       0.000000       0.000000
# ...

# %%
#           Simple Linear Regression
#The coefficients, the residual sum of squares and the variance score are also calculated.
# Simple Linear Regression -Try 1

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
y_final = d_flights['ARR_DELAY'].values
#Two features- simple linear regression
X_final= d_flights[['DISTANCE', 'CRS_ARR_TIME']].astype('float')

# %%
# Split the data into training/testing sets
flight_X_train = X_final[:-20]  #everything except last 20 items
flight_X_test = X_final[-20:]   #last 20 items
# Split the targets into training/testing sets
flight_y_train = y_final[:-20]
flight_y_test = y_final[-20:]

# %%
# Create linear regression object -- no alpha
regr = linear_model.LinearRegression()

# %%
# Train the model using the training sets
regr.fit(flight_X_train, flight_y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Make predictions using the testing set
flight_y_pred = regr.predict(flight_X_test)

# %%
# The coefficients
print('Coefficients: \n', regr.coef_)
# Out:
# ('Coefficients: \n', array([-0.00361495,  0.34262608]))

# %%
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(flight_y_test, flight_y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(flight_y_test, flight_y_pred))
# Out:
# Mean squared error: 851.18
# Variance score: -0.06

# %%
#Print y and predicted
from sklearn.model_selection import cross_val_predict
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
X= d_flights[['DISTANCE', 'CRS_ARR_TIME']].astype('float')
y = d_flights['ARR_DELAY'].values
lr = linear_model.LinearRegression()
# cross_val_predict returns an array of the same size as `y` where each entry
# is a prediction obtained by cross validation:
predicted = cross_val_predict(lr, X, y, cv=10)
fig, ax = plt.subplots()
ax.scatter(y_final, predicted, edgecolors=(0, 0, 0))
ax.plot([y.min(), y.max()], [predicted.min(), predicted.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()

# %%
# Another Simple Linear Regression prediction - No 2
# Feature selected
# Based on HillClimbing Tech

# %%
#One feature- simple linear regression
y_final = d_flights['ARR_DELAY'].values
X_final= d_flights[['MONTH']].astype('float')

# %%
# Split the data into training/testing sets
flight_X_train = X_final[:-20]  #everything except last 20 items
flight_X_test = X_final[-20:]   #last 20 items
# Split the targets into training/testing sets
flight_y_train = y_final[:-20]
flight_y_test = y_final[-20:]

# %%
# Create linear regression object -- no alpha
regr = linear_model.LinearRegression()

# %%
# Train the model using the training sets
regr.fit(flight_X_train, flight_y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Make predictions using the testing set
flight_y_pred = regr.predict(flight_X_test)

# %%
# The coefficients
print('Coefficients: \n', regr.coef_)
# Out:
# ('Coefficients: \n', array([-0.51871174]))

# %%
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(flight_y_test, flight_y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(flight_y_test, flight_y_pred))
# Out:
# Mean squared error: 840.15
# Variance score: -0.05

# %%
# Plot outputs(available for one feature in Linear Regression) 
plt.scatter(flight_X_test, flight_y_test,  color='black')
plt.plot(flight_X_test, flight_y_pred, color='blue', linewidth=3)

# %%
#Print y and predicted
from sklearn.model_selection import cross_val_predict
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
X= d_flights[['DISTANCE', 'CRS_ARR_TIME']].astype('float')
y = d_flights['ARR_DELAY'].values
lr = linear_model.LinearRegression()
# cross_val_predict returns an array of the same size as `y` where each entry
# is a prediction obtained by cross validation:
predicted = cross_val_predict(lr, X, y, cv=10)
fig, ax = plt.subplots()
ax.scatter(y_final, predicted, edgecolors=(0, 0, 0))
ax.plot([y.min(), y.max()], [predicted.min(), predicted.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()

# %%
#End of Simple Linear Regression- No 2

# %%
#       Simple Linear Regression- No 3

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
y_final = d_flights['ARR_DELAY'].values

# %%
####    8 Features
X_final= d_flights[['MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'UNIQUE_CARRIER', 'ORIGIN_AIRPORT_ID', 'DEST_AIRPORT_ID', 'CRS_DEP_TIME', 
                    'CRS_ARR_TIME']]

# %%
# Split the data into training/testing sets
flight_X_train = X_final[:-20]
flight_X_test = X_final[-20:]

# Split the targets into training/testing sets
flight_y_train = y_final[:-20]
flight_y_test = y_final[-20:]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(flight_X_train, flight_y_train)

# Make predictions using the testing set
flight_y_pred = regr.predict(flight_X_test)

# %%
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(flight_y_test, flight_y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(flight_y_test, flight_y_pred))
# Out:
# ('Coefficients: \n', array([-0.50325515, -0.16088553, -0.19142996,  0.31294733,  0.00078111,
#         0.00103396,  0.0012116 ,  0.0012116 ,  0.00191351]))
# Mean squared error: 889.62
# Variance score: -0.11

# %%
regr.intercept_
# Out:
# -24.219078607109505

# %%
#End of Simple Linear Regression- No 3

# %%
#####      End of Simple Linear Regression

# %%
d_flights['DISTANCE'] = d_flights['DISTANCE'].astype('float64')
d_flights['UNIQUE_CARRIER'] = d_flights['UNIQUE_CARRIER'].astype('int64')
d_flights['ORIGIN_AIRPORT_ID'] = d_flights['ORIGIN_AIRPORT_ID'].astype('int64')
d_flights['DEST_AIRPORT_ID'] = d_flights['DEST_AIRPORT_ID'].astype('int64')
d_flights['CRS_DEP_TIME'] = d_flights['CRS_DEP_TIME'].astype('int64')
d_flights['CRS_ARR_TIME'] = d_flights['CRS_ARR_TIME'].astype('int64')
d_flights['ARR_DELAY'] = d_flights['ARR_DELAY'].astype('int64')

# %%
######     Ridge Regression   ########################

# %%
###  Ridge Try1 ## Using Scaling
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
y_final = d_flights['ARR_DELAY'].values
# 2 Features
X_final= d_flights[['DISTANCE', 'CRS_ARR_TIME']]

# %%
# Split the data into training/testing sets
flight_X_train = X_final[:-20]  #everything except last 20 items
flight_X_test = X_final[-20:]   #last 20 items
# Split the targets into training/testing sets
flight_y_train = y_final[:-20]
flight_y_test = y_final[-20:]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(flight_X_train)  #  fit only on training data
X_train_scaled = scaler.transform(flight_X_train)
X_test_scaled = scaler.transform(flight_X_test)  # apply same transformation to test data

# %%
#As with other linear models, Ridge will take in its fit method arrays X, y and will store the coefficients w of the linear model in its coef_ member:
from sklearn.linear_model import Ridge
#Create Ridge regression object and Train the model using the training sets
linRidge=Ridge(alpha=100.0).fit(X_train_scaled,flight_y_train)

# %%
print('Coefficients: \n', linRidge.coef_)
# Make predictions using the testing set
flight_y_pred = linRidge.predict(X_test_scaled)
print("Mean squared error: %.2f"
      % mean_squared_error(flight_y_test, flight_y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(flight_y_test, flight_y_pred))
# Out:
# ('Coefficients: \n', array([-9.48188004,  8.03259453]))
# Mean squared error: 850.58
# Variance score: -0.06

# %%
linRidge.intercept_
# Out:
# 1.158007187247196

# %%
#####  End of Ridge-Try1

# %%
###  Ridge Try2 ## Using Scaling
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
y_final = d_flights['ARR_DELAY'].values
# 1 Feature
X_final= d_flights[['MONTH']]

# %%
# Split the data into training/testing sets
flight_X_train = X_final[:-20]  #everything except last 20 items
flight_X_test = X_final[-20:]   #last 20 items
# Split the targets into training/testing sets
flight_y_train = y_final[:-20]
flight_y_test = y_final[-20:]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(flight_X_train)  # fit only on training data
X_train_scaled = scaler.transform(flight_X_train)
X_test_scaled = scaler.transform(flight_X_test)  # apply same transformation to test data

# %%
#As with other linear models, Ridge will take in its fit method arrays X, y and will store the coefficients w of the linear model in its coef_ member:
from sklearn.linear_model import Ridge
#Create Ridge regression object and Train the model using the training sets
linRidge=Ridge(alpha=100.0).fit(X_train_scaled,flight_y_train)

# %%
print('Coefficients: \n', linRidge.coef_)
# Make predictions using the testing set
flight_y_pred = linRidge.predict(X_test_scaled)
print("Mean squared error: %.2f"
      % mean_squared_error(flight_y_test, flight_y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(flight_y_test, flight_y_pred))
# Out:
# ('Coefficients: \n', array([-5.68470197]))
# Mean squared error: 840.03
# Variance score: -0.05

# %%
linRidge.intercept_
# Out:
# 5.162718814138854

# %%
#####  End of Ridge-Try2

# %%
###  Ridge Try3 ## Using Scaling
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
y_final = d_flights['ARR_DELAY'].values
# 8 Features
X_final= d_flights[['MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'UNIQUE_CARRIER', 'ORIGIN_AIRPORT_ID', 'DEST_AIRPORT_ID', 'CRS_DEP_TIME', 
                    'CRS_ARR_TIME']]

# %%
# Split the data into training/testing sets
flight_X_train = X_final[:-20]  #everything except last 20 items
flight_X_test = X_final[-20:]   #last 20 items
# Split the targets into training/testing sets
flight_y_train = y_final[:-20]
flight_y_test = y_final[-20:]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(flight_X_train)  # fit only on training data
X_train_scaled = scaler.transform(flight_X_train)
X_test_scaled = scaler.transform(flight_X_test)  # apply same transformation to test data

# %%
#As with other linear models, Ridge will take in its fit method arrays X, y and will store the coefficients w of the linear model in its coef_ member:
from sklearn.linear_model import Ridge
#Create Ridge regression object and Train the model using the training sets
linRidge=Ridge(alpha=100.0).fit(X_train_scaled,flight_y_train)

# %%
print('Coefficients: \n', linRidge.coef_)
# Make predictions using the testing set
flight_y_pred = linRidge.predict(X_test_scaled)
print("Mean squared error: %.2f"
      % mean_squared_error(flight_y_test, flight_y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(flight_y_test, flight_y_pred))
# Out:
# ('Coefficients: \n', array([-5.51618378, -4.80756677, -1.14536522,  4.36722477,  4.0711153 ,
#         5.37873581,  5.67988594,  4.50241035]))
# Mean squared error: 889.14
# Variance score: -0.11

# %%
linRidge.intercept_
# Out:
# -6.298577471007079

# %%
#####  End of Ridge-Try3

# %%
####   Logestic Regression    #####  Target value shoyuld be Binary
import numpy as np
from sklearn import preprocessing
from pandas import Series, DataFrame
import matplotlib.pyplot as plt 
plt.rc("font", size=14)
from pylab import rcParams
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split
from sklearn import metrics 
from sklearn.metrics import classification_report
# Out:
# D:\Users\Admin\Anaconda2\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#Adding a boolean column corresponding to the numerical column 'ARR_DELAY' as the target
d_flights['ARR_DELAY_Boolean'] = np.where(d_flights['ARR_DELAY']==50, 'no', 'yes')
#d_flights['ARR_DELAY_Boolean'] = np.where(d_flights['ARR_DELAY']==50, '0', '1')

# %%
d_flights['DISTANCE'] = d_flights['DISTANCE'].astype('float64')
d_flights['UNIQUE_CARRIER'] = d_flights['UNIQUE_CARRIER'].astype('int64')
d_flights['ORIGIN_AIRPORT_ID'] = d_flights['ORIGIN_AIRPORT_ID'].astype('int64')
d_flights['DEST_AIRPORT_ID'] = d_flights['DEST_AIRPORT_ID'].astype('int64')
d_flights['CRS_DEP_TIME'] = d_flights['CRS_DEP_TIME'].astype('int64')
d_flights['CRS_ARR_TIME'] = d_flights['CRS_ARR_TIME'].astype('int64')
d_flights['ARR_DELAY'] = d_flights['ARR_DELAY'].astype('int64')

# %%
y_final = d_flights['ARR_DELAY_Boolean'].values
# 8 features
X_final= d_flights[['MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'UNIQUE_CARRIER', 'ORIGIN_AIRPORT_ID', 'DEST_AIRPORT_ID', 'CRS_DEP_TIME', 
                    'CRS_ARR_TIME']]

# %%
# Split the data into training/testing sets
X_train = X_final[:-20]  #everything except last 20 items
X_test = X_final[-20:]   #last 20 items
# Split the targets into training/testing sets
y_train = y_final[:-20]
y_test = y_final[-20:]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_final, y_final, random_state=0)

# %%
X_train.shape
# Out:
# (220481, 8)

# %%
classifier = LogisticRegression(random_state=0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=0, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)
# Out:
# [[    0   101]
#  [    0 73393]]

# %%
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(classifier.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 1.00

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#          no       0.00      0.00      0.00       101
#         yes       1.00      1.00      1.00     73393
#
# avg / total       1.00      1.00      1.00     73494
# D:\Users\Admin\Anaconda2\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
#Visualizatiologistic regression classsifiers’ decision boundaries
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
#X = X_final.loc[:,1:]
#y = y_final.loc[:,0]
X = X_final
y = y_final
pca = PCA(n_components=2).fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(pca, y, random_state=0)

plt.figure(dpi=120)
plt.scatter(pca[y.values==0,0], pca[y.values==0,1], alpha=0.5, label='YES', s=2, color='navy')
plt.scatter(pca[y.values==1,0], pca[y.values==1,1], alpha=0.5, label='NO', s=2, color='darkorange')
plt.legend()
plt.title('Flight Data Set\nFirst Two Principal Components')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.gca().set_aspect('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-fcb27eeb6a57> in <module>()
#      10
#      11 plt.figure(dpi=120)
# ---> 12 plt.scatter(pca[y.values==0,0], pca[y.values==0,1], alpha=0.5, label='YES', s=2, color='navy')
#      13 plt.scatter(pca[y.values==1,0], pca[y.values==1,1], alpha=0.5, label='NO', s=2, color='darkorange')
#      14 plt.legend()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
####   End of Logiostic Regression     #######

# %%
# Another  Ridge Regression - with scaling and SGD_Regressor

# %%
scalingDF = d_flights[['DISTANCE']].astype('float') # Numerical features

# %%
categDF = d_flights[[ 'DAY_OF_MONTH', 'ORIGIN_AIRPORT_ID', 'DEST_AIRPORT_ID', 'CRS_ARR_TIME', 'CRS_DEP_TIME', 
                   'UNIQUE_CARRIER', 'DAY_OF_WEEK']] # Categorical features

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder() # Create encoder object
categDF_encoded = encoder.fit_transform(categDF) # Can't convert this to dense array: too large!

# %%
type(categDF_encoded)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
from scipy import sparse # Need this to create a sparse array, so more speed
scalingDF_sparse = sparse.csr_matrix(scalingDF)

# %%
x_final = sparse.hstack((scalingDF_sparse, categDF_encoded))

# %%
y_final = d_flights['ARR_DELAY'].values

# %%
from sklearn.cross_validation import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_final,y_final,test_size = 0.2,random_state = 0) # Do 80/20 split

# %%
x_train_numerical = x_train[:, 0:2].toarray() # We only want the first two features which are the numerical ones.
x_test_numerical = x_test[:, 0:2].toarray()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() # create scaler object
scaler.fit(x_train_numerical) # fit with the training data ONLY
x_train_numerical = sparse.csr_matrix(scaler.transform(x_train_numerical)) # Transform the data and convert to sparse
x_test_numerical = sparse.csr_matrix(scaler.transform(x_test_numerical))

# %%
x_train[:, 0:2] = x_train_numerical
x_test[:, 0:2] = x_test_numerical
# Out:
# D:\Users\Admin\Anaconda2\lib\site-packages\scipy\sparse\compressed.py:742: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   SparseEfficiencyWarning)

# %%
# Training the modelfrom sklearn.linear_model import SGDRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.grid_search import GridSearchCV
import numpy as np

SGD_params = {'alpha': 10.0**-np.arange(1,7)} # Suggested range we try
SGD_model = GridSearchCV(SGDRegressor(random_state = 0), SGD_params, scoring = 'mean_absolute_error', cv = 5) # Use 5-fold CV 
SGD_model.fit(x_train, y_train) # Fit the model
# Out:
# D:\Users\Admin\Anaconda2\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# D:\Users\Admin\Anaconda2\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# D:\Users\Admin\Anaconda2\lib\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_absolute_error was renamed to neg_mean_absolute_error in version 0.18 and will be removed in 0.20.
# ...

# %%
#End of Ridge Regression while there are points of improvements such as 
#making a function to predict flight delays with using SGD_model.predict()
#to predict flight delay

# %%
#Functions for predicting flight delay

# %%
airport_lookupDF = pd.read_csv('Airport_Lookup.csv', header = 0) # Airport codes

# %%
#    This is a function for the delay prediction function to use for calculating the number of 
#    flights in the database for a given city.    
#    Inputs: list of codes retrived in the delay_prediction function
#   Output: The code with the largest number of flights.

# %%
def max_num_flights(codes):
    num_store = np.zeros(len(codes)) # Store all possible airport codes
    
    if len(codes) < 1:
        print('Try entering your city/airport again. No matching airports found.') # In case the aiport didn't show up 
        return                                                                     # in the data
    
    for i in xrange(len(codes)):
        num_flights = d_flights.MONTH[d_flights.ORIGIN_AIRPORT_ID == codes[i]].count() # Count number of rows in data for each
        num_store[i] = num_flights                                                 # airport code
       
    max_ind = int(np.where(num_store == max(num_store))[0]) #Finds the maximum row
    # Now we know which code had the most flights. Return it.
    return(codes[max_ind])

# %%
#    This function allows you to input all of your flight information (no leaks!) and
#    the function will return how late your flight will arrive based on the output from the 
#    SGD Regressor.    
#    Inputs:     
#         Origin (enter this as a city, state combo, or include the airport name (such as Bush
#                     or Hobby). This will automatically calculate which airport you meant.             
#         Destination (same as Origin, entered as a string)             
#         Carrier (which Airline, use a string to represent the name (such as 'American' or 'United')            
#         Departing Hour scheduled (just the hour of departure, based on a 24 hour cycle. This means
#                             noon would be 12, and midnight would be 0.)             
#         Arriving Hour scheduled (same format as departing)             
#         Month (the month the flight is scheduled for)             
#         Day (the day of the month the flight is scheduled for)             
#         Weekday (Enter as a capitalized word, such as 'Monday')            
#         Available Carriers: United, Alaska,..

# %%
def delay_prediction(origin = 'Fort Worth', destination = 'Chicago', carrier = 'American', 
                      dept_time = 17, arr_time = 19, month = 5, day = 15, weekday = 'Wednesday'):
        # Create a dict for our Airlines. Based on the carrierDF.
     
    carrier_dict = {'Spirit':1, 'American':2, 'Alaska':3, 'JetBlue':4, 'Delta':5,
                     'ExpressJet':6, 'Frontier':7, 'AirTran':8, 'Hawaiian':9, 'Envoy':10,
                     'SkyWest':11, 'United':12, 'US Airways':13, 'Virgin':14,
                     'Southwest':15, 'Mesa':16}
                     
    # Another for day of the week
     
    weekday_dict = {'Monday':1, 'Tuesday':2, 'Wednesday':3, 'Thursday':4,
                     'Friday':5, 'Saturday':6, 'Sunday':7}
                     
    # Now find the corresponding airport codes for our origin and destination. 
     
    origin_codes = list(airport_lookupDF[airport_lookupDF.Description.str.contains(origin)].Code)
    destination_codes = list(airport_lookupDF[airport_lookupDF.Description.str.contains(destination)].Code)
     
    # From these codes found in the lookup table, see which one had the largest number of flights.
                                                                                                                                                                                                                                                                                                                                     
    origin_code = max_num_flights(origin_codes)
    destination_code = max_num_flights(destination_codes)
     
    # Now that we have these codes, we can look up the other parameters necessary.
    # Now find the distance between the two airports. Add a try/except to catch any problems.
   
    try:
        distance = np.array(float(d_flights[(d_flights.ORIGIN_AIRPORT_ID == origin_code) & 
                              (d_flights.DEST_AIRPORT_ID == destination_code)].DISTANCE.drop_duplicates()))
    except:
        print 'Route was not found in the data. Please try a different nearby city or a new route.'
        return
     
    carrier_num = carrier_dict[carrier]
    weekday_num = weekday_dict[weekday]
     
    # Now that we have all of our values, we can start combining them together.
     
    # First, create our numeric array of distance.

    
    numerical_values = np.c_[distance]
     
    # Scale the features
     
    numerical_values_scaled = scaler.transform(numerical_values)
     
    # Now create our array of categorical values.
     
    categorical_values = np.zeros(8)
    categorical_values[0] = int(month)
    categorical_values[1] = int(day)
    categorical_values[2] = int(origin_code)
    categorical_values[3] = int(destination_code)
    categorical_values[4] = int(arr_time)
    categorical_values[5] = int(dept_time)
    categorical_values[6] = int(carrier_num)
    categorical_values[7] = int(weekday_num)
     
    # Apply the one-hot encoding to these.
     
    categorical_values_encoded = encoder.transform([categorical_values]).toarray()
     
    # Combine these into the final test example that goes into the model
     
    final_test_exmpl = np.c_[numerical_values_scaled, categorical_values_encoded]
     
    # Now predict this with the model 
     
    pred_delay = SGD_model.predict(final_test_exmpl)
    print 'Your predicted delay is', int(pred_delay[0]), 'minutes.'
    return # End of function

# %%
delay_prediction(origin = 'Chicago', destination = 'Dallas', 
                  carrier = 'United', dept_time = 17, arr_time = 21,
                  month = 3, day = 19, weekday = 'Thursday')
# Out:
# Route was not found in the data. Please try a different nearby city or a new route.

# %%
delay_prediction(origin = 'Dallas', destination = 'Seattle/Tacoma International', 
                  carrier = 'American', dept_time = 17, arr_time = 20,
                  month = 1, day = 28, weekday = 'Wednesday')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-47146b3d1422> in <module>()
#       1 delay_prediction(origin = 'Dallas', destination = 'Seattle/Tacoma International',
#       2                   carrier = 'American', dept_time = 17, arr_time = 20,
# ----> 3                   month = 1, day = 28, weekday = 'Wednesday')
#
# <ipython-input-78-4bc8a04689e3> in delay_prediction(origin, destination, carrier, dept_time, arr_time, month, day, weekday)
#      51     # Scale the features
#      52
# ---> 53     numerical_values_scaled = scaler.transform(numerical_values)
#      54
#      55     # Now create our array of categorical values.
#
# D:\Users\Admin\Anaconda2\lib\site-packages\sklearn\preprocessing\data.pyc in transform(self, X, y, copy)
#     690         else:
#     691             if self.with_mean:
# --> 692                 X -= self.mean_
# ...

# %%
delay_prediction(origin = 'Dallas', destination = 'Chicago', 
                  carrier = 'American', dept_time = 10, arr_time = 13,
                  month = 1, day = 28, weekday = 'Wednesday')
# Out:
# Route was not found in the data. Please try a different nearby city or a new route.

# %%
######       End of Asssignment 2 - PDS        ######################
